# %% [markdown]
# # Image Classification with Keras

# %% [markdown]
# ## Predicting an Image’s Category

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.layers import Input, Flatten, Dense, Dropout, GlobalAveragePooling2D
from keras.applications.resnet50 import ResNet50
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.preprocessing import image

import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_path = 'samples/cat1.png'

img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.show()

# %%
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)

# %%
img_array.shape
# Out:
# (224, 224, 3)

# %%
img_batch.shape
# Out:
# (1, 224, 224, 3)

# %%
model = ResNet50()

img_preprocessed = preprocess_input(img_batch)

prediction = model.predict(img_preprocessed)

decode_predictions(prediction, top=3)[0]
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 294s 3us/step
# [('n02123045', 'tabby', 0.4273132),
#  ('n02124075', 'Egyptian_cat', 0.34517565),
#  ('n02123159', 'tiger_cat', 0.06041771)]

# %%
prediction.shape
# Out:
# (1, 1000)

# %%
img_path = 'samples/dog1.png'

img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.show()

# %%
model = ResNet50()

img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = preprocess_input(img_batch)

prediction = model.predict(img_preprocessed)
decode_predictions(prediction, top=3)[0]
# Out:
# [('n02113186', 'Cardigan', 0.822284),
#  ('n02113023', 'Pembroke', 0.17369337),
#  ('n02110806', 'basenji', 0.0011249685)]
